# %% [markdown]
# Empiece con el programa del ejercicio 8-7.
# Escriba un bucle while que permita a los usuarios introducir el artista y el
# título de un álbum. Una vez que disponga de esa información, llame a
# hacer_album() con la entrada de usuario e imprima el diccionario que se ha
# creado. Asegúrese de incluir un valor para salir en el bucle while.

# %%
def hacer_album(artista, nombre_album):
    """Devuelve un diccionario con información acerca de un album"""
    album = {'artista': artista, 'nombre_album': nombre_album}

    return album

while True:
    print('\nIngresa el nombre de un artista y uno de sus albumes:')
    print('(ingresa "q" en cualquier momento para terminar el programa)')

    f_artista = input('Nombre del artista: ')
    if f_artista == 'q':
      break

    f_nombre_album = input('Nombre del album: ')
    if f_nombre_album == 'q':
      break

    nuevo_album = hacer_album(f_artista, f_nombre_album)
    print(f'\n{f_artista.title()} hizo {f_nombre_album}')
# Out:
# Ingresa el nombre de un artista y uno de sus albumes:
# (ingresa "q" en cualquier momento para terminar el programa)
# Nombre del artista: Luis Miguel
# Nombre del album: Romance
#
# Luis Miguel hizo Romance
#
# Ingresa el nombre de un artista y uno de sus albumes:
# (ingresa "q" en cualquier momento para terminar el programa)
# Nombre del artista: Mark Foster
# Nombre del album: torches
#
# Mark Foster hizo torches
#
# Ingresa el nombre de un artista y uno de sus albumes:
# (ingresa "q" en cualquier momento para terminar el programa)
# Nombre del artista: Mark Foster
# Nombre del album: q
