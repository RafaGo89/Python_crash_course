# %%
# Creamos una tupla
dimensions = (200, 50)

# Accedemos a los valores de la tupla por sus índices
print(dimensions[0])
print(dimensions[1])
# Out:
# 200
# 50

# %%
dimensions = (200, 50)

# Usamos un ciclo for para iterar los elementos de la tupla
for dimension in dimensions:
    print(dimension)
# Out:
# 200
# 50

# %%
dimensions = (200, 50)

print('Original dimensions:')

for dimension in dimensions:
    print(dimension)

# Aunque no se pueda cambiar una tupla, se pueden rehacer la tupla
dimensions = (400, 100)

print('\nModified dimensions:')

for dimension in dimensions:
    print(dimension)
# Out:
# Original dimensions:
# 200
# 50
#
# Modified dimensions:
# 400
# 100
