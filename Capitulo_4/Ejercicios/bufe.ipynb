# %% [markdown]
# Un restaurante de tipo bufé ofrece solo cinco comidas básicas.
# Piense en cinco platos básicos y guárdelos en una tupla.
# * Use un bucle for para imprimir cada comida que ofrece el restaurante.
# * Intente modificar alguno de los elementos y asegúrese de que Python
# rechaza el cambio.
# * El restaurante cambia su menú, sustituyendo dos elementos por comidas
# diferentes. Añada una línea que rehaga la tupla y use un bucle for para
# imprimir cada uno de los elementos del menú modificado.

# %%
# Creamos una tupla
bufe = ('ensalada', 'pasta', 'puré de papa', 'sopa', 'caldo de pollo')

for platillo in bufe:
    print(platillo)
# Out:
# ensalada
# pasta
# puré de papa
# sopa
# caldo de pollo

# %%
# Esto dará un error
bufe[0] = 'pescado'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4211752072.py in <cell line: 0>()
#       1 # Esto dará un error
# ----> 2 bufe[0] = 'pescado'
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Rehacemos la tupla
bufe = ('milanesa de pollo', 'empanadas', 'puré de papa', 'sopa', 'caldo de pollo')

for platillo in bufe:
    print(platillo)
# Out:
# milanesa de pollo
# empanadas
# puré de papa
# sopa
# caldo de pollo
