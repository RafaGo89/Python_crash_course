# %% [markdown]
# Think of at least three different animals that have a common characteristic. Store the names of these animals in a list, and then use a for loop to
# print out the name of each animal.
# * Modify your program to print a statement about each animal, such as A
# dog would make a great pet.

# %%
# Creamos una lista de animales
animals = ['dolphin', 'whale', 'turtle']

# Imprimimos los animales de la lista
for animal in animals:
  print(animal)
# Out:
# dolphin
# whale
# turtle

# %%
animals = ['dolphin', 'whale', 'turtle']

# Añadimos una frase
for animal in animals:
  print(f'A {animal} would make a great pet.')
# Out:
# A dolphin would make a great pet.
# A whale would make a great pet.
# A turtle would make a great pet.

# %%
animals = ['dolphin', 'whale', 'turtle']

# Añadimos una frase fuera del ciclo for
for animal in animals:
  print(f'A {animal} would make a great pet.')

print('\nAny of these animal would make a great pet')
# Out:
# A dolphin would make a great pet.
# A whale would make a great pet.
# A turtle would make a great pet.
#
# Any of these animal would make a great pet
