# %%
responses = {}

# Ponemos una bandera para especificar que la encuesta está activa
polling_active = True

while polling_active:
    # Pedimos el nombre y respuesta de la persona
    name = input('\nWhat is your name? ')
    response = input('Which mountain would you like to climb someday? ')

    # Guardamos la respuesta en un diccionario
    responses[name] = response

    # Preguntamos si otra persona contestará la encuesta
    repeat = input('Would you like to let another person respond? (yes/no) ')
    if repeat == 'no':
        polling_active = False

# Mostramos los resultados de la encuesta
print('\n--- Poll results ---')
for name, response in responses.items():
    print(f"{name} would like to climb {response}")
# Out:
# What is your name? Rafa
# Which mountain would you like to climb someday? Everest
# Would you like to let another person respond? (yes/no) yes
#
# What is your name? Thiare
# Which mountain would you like to climb someday? Pico de orizaba
# Would you like to let another person respond? (yes/no) yes
#
# What is your name? Julian
# Which mountain would you like to climb someday? Nevado de colima
# Would you like to let another person respond? (yes/no) no
#
# --- Poll results ---
# Rafa would like to climb Everest
# Thiare would like to climb Pico de orizaba
# Julian would like to climb Nevado de colima
