# %% [markdown]
# Un cine cobra las entradas a distinto precio en
# función de la edad del espectador. Los menores de 3 años entran gratis, los
# niños de entre 3 y 12 años pagan 8 euros y la entrada para mayores de 12
# años cuesta 12 euros. Escriba un bucle para preguntar a los usuarios su edad
# y luego dígales el precio de su entrada.

# %%
prompt = '\nHow old are you? '
prompt += "(Enter 'quit' when you are done) "

active = True
age = ''

while active:
    age = input(prompt)

    if age.lower() == 'quit':
        active = False
    else:
        age = int(age)
        if age < 3:
            print('Your ticket is free!')
        elif age >= 3 and age <= 12:
            print('Your ticket is €8')
        else:
            print('Your ticket is €12')
# Out:
# How old are you? (Enter 'quit' when you are done) 2
# Your ticket is free!
#
# How old are you? (Enter 'quit' when you are done) 3
# Your ticket is €8
#
# How old are you? (Enter 'quit' when you are done) 12
# Your ticket is €8
#
# How old are you? (Enter 'quit' when you are done) 13
# Your ticket is €12
#
# How old are you? (Enter 'quit' when you are done) QUIT

# %%
prompt = '\nHow old are you? '
prompt += "(Enter 'quit' when you are done) "

age = ''

while True:
    age = input(prompt)

    if age.lower() == 'quit':
        break

    age = int(age)
    if age < 3:
        print('Your ticket is free!')
    elif age >= 3 and age <= 12:
        print('Your ticket is €8')
    else:
        print('Your ticket is €12')
# Out:
# How old are you? (Enter 'quit' when you are done) 1
# Your ticket is free!
#
# How old are you? (Enter 'quit' when you are done) 4
# Your ticket is €8
#
# How old are you? (Enter 'quit' when you are done) 14
# Your ticket is €12
#
# How old are you? (Enter 'quit' when you are done) 21
# Your ticket is €12
#
# How old are you? (Enter 'quit' when you are done) QUIT
