# %% [markdown]
#  Escriba un programa que pregunte al usuario qué
# tipo de coche desea alquilar. Imprima un mensaje sobre el coche, como
# "Veamos si tenemos un Subaru para usted"

# %%
rental_car = input('What kind of car would you like to rent? ')
print(f"Let's see if we got a {rental_car.title()} for you")
# Out:
# What kind of car would you like to rent? tsuru
# Let's see if we got a Tsuru for you
